# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashikur-ai/Learn-Tensorflow/blob/main/5_Cats_Vs_Dogs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# * os - to read files and directory structure
# * numpy - for some matrix math outside of tensorflow
# * matplotlib.pyplot - to plot the graph and display images in our training and validation data

# %%
import tensorflow as tf

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
import logging
logger = tf.get_logger()
logger.setLevel(logging.ERROR)

# %% [markdown]
# #Data Loading

# %% [markdown]
# To build our image classifier, we begin by downloading the dataset. The dataset we are using is a filtered version of Dogs vs. Cats dataset from Kaggle (ultimately, this dataset is provided by Microsoft Research).
#
# In previous Colabs,we've used TensorFlow Datasets, which is a very easy and convenient way to use datasets. In this Colab however, we will make use of the class `tf.keras.preprocessing.image.ImageDataGenerator` which will read data from disk. We therefore need to directly download Dogs vs. Cats from a URL and unzip it to the Colab filesystem.

# %%
_URL = 'https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip'
zip_dir = tf.keras.utils.get_file('cats_and_dogs_filtered.zip', origin=_URL, extract=True)
# Out:
# Downloading data from https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# 68608000/68606236 [==============================] - 0s 0us/step
# 68616192/68606236 [==============================] - 0s 0us/step

# %% [markdown]
# We can list the directories with the following terminal command:

# %%
zip_dir_base = os.path.dirname(zip_dir)
# !find $zip_dir_base -type d -print
# Out:
# /root/.keras/datasets
# /root/.keras/datasets/cats_and_dogs_filtered
# /root/.keras/datasets/cats_and_dogs_filtered/train
# /root/.keras/datasets/cats_and_dogs_filtered/train/dogs
# /root/.keras/datasets/cats_and_dogs_filtered/train/cats
# /root/.keras/datasets/cats_and_dogs_filtered/validation
# /root/.keras/datasets/cats_and_dogs_filtered/validation/dogs
# /root/.keras/datasets/cats_and_dogs_filtered/validation/cats

# %%
base_dir = os.path.join(os.path.dirname(zip_dir), 'cats_and_dogs_filtered')
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation')

train_cats_dir = os.path.join(train_dir, 'cats') # directory with our training cat pictures
train_dogs_dir = os.path.join(train_dir, 'dogs') # directory with our training dog image
validation_cats_dir = os.path.join(validation_dir, 'cats') # directory with our validation cat pictures
validation_dogs_dir = os.path.join(validation_dir, 'dogs') # directory with our validation dog pictures

# %% [markdown]
# #Understanding our data

# %% [markdown]
# Let's look at how many cats and dogs images we have in our training and validation directory

# %%
num_cats_tr = len(os.listdir(train_cats_dir))
num_dogs_tr = len(os.listdir(train_dogs_dir))

num_cats_val = len(os.listdir(validation_cats_dir))
num_dogs_val = len(os.listdir(validation_dogs_dir))

total_train = num_cats_tr + num_dogs_tr
total_val = num_cats_val + num_dogs_val

# %%
print('total training cat images:', num_cats_tr)
print('total training dog images:', num_dogs_tr)

print('total validation cat images:', num_cats_val)
print('total validation dog images:', num_dogs_val)
print('--')
print('Total training images:', total_train)
print('Total validation images:', total_val)
# Out:
# total training cat images: 1000
# total training dog images: 1000
# total validation cat images: 500
# total validation dog images: 500
# --
# Total training images: 2000
# Total validation images: 1000

# %% [markdown]
# #Setting Model Parameters

# %% [markdown]
# For convenience, we'll set up variables that will be used later while pre-processing our dataset and training our network.

# %%
BATCH_SIZE = 10 # Number of training examples to process before updating our models variables
IMG_SHAPE = 150 # Our training data consists of images with width of 150 pixedls and height of 150 pixels

# %% [markdown]
# #Data Preparation

# %% [markdown]
# Images must be formatted into appropriately pre-processed floating point tensors before being fed into the network.The steps involved in preparing these images are:
# 1. Read images from the disk
# 2. Decode contents of these images and convert it into proper grid format as per their RGB content
# 3. Convert them into floating point tensors
# 4. Rescale the tensors from values between 0 and 255 to values between 0 and 1, as neural network prefer to deal with small input values.
# Fortunately, all these tasks can be done using the class
# **tf.keras.preprocessing.image.ImageDataGenerator**
#
# We can set this up in a couple of lines of code.

# %%
train_image_generator     = ImageDataGenerator(rescale=1./255) # Generator for our training data
validation_image_generator = ImageDataGenerator(rescale=1./255) # Generator for our validation data

# %% [markdown]
# After defining our generators for training and validation images, **flow_from_directory** method will load images from the disk, apply rescaling, and resize them useing single line of code.

# %%
train_data_gen = train_image_generator.flow_from_directory(batch_size=BATCH_SIZE,
                                                           directory=train_dir,
                                                           shuffle=True,
                                                           target_size=(IMG_SHAPE, IMG_SHAPE), #(150, 150 )
                                                           class_mode='binary')
# Out:
# Found 2000 images belonging to 2 classes.

# %%
val_data_gen = validation_image_generator.flow_from_directory(batch_size=BATCH_SIZE,
                                                              directory=validation_dir,
                                                              shuffle=False,
                                                              target_size=(IMG_SHAPE, IMG_SHAPE),
                                                              class_mode='binary')
# Out:
# Found 1000 images belonging to 2 classes.

# %% [markdown]
# #Visualizing Training images
# We can visualize our training images by getting a batch of images from the training generator, and then plotting a few of them using `matplotlib`

# %%
sample_training_images, _ = next(train_data_gen)

# %% [markdown]
# the `next` function returns a batch from the dataset. One batch is a tuple of (many images, many labels).For right now, we're discarding the labels because we just want to look at the images.

# %%
# This function will plot images in the form of a grid with 1 row and 5 columns where images are placed in each column 
def plotImages(images_arr):
  fig, axes = plt.subplots(1, 5, figsize=(20, 20))
  axes = axes.flatten()
  for img, ax in zip(images_arr, axes):
    ax.imshow(img)
  plt.tight_layout()
  plt.show()

# %%
plotImages(sample_training_images[:5]) #plot images 0-4

# %% [markdown]
# #Model Creation

# %% [markdown]
# ##Define the model
# The model consists of four convolution blocks with a max pool layer in each of them. Then we have a fully connected layer with 512 units, with a `relu` activation function. The model will output class probabilities for two classes- dogs and cats - using `softmax`

# %%
model = tf.keras.models.Sequential([
     tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)),
     tf.keras.layers.MaxPooling2D(2, 2),

     tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
     tf.keras.layers.MaxPooling2D(2,2),

     tf.keras.layers.Conv2D(128, (3,3),activation='relu'),
     tf.keras.layers.MaxPooling2D(2,2),

     tf.keras.layers.Conv2D(128, (3,3),activation='relu'),
     tf.keras.layers.MaxPooling2D(2,2),

     tf.keras.layers.Flatten(),
     tf.keras.layers.Dense(512, activation='relu'),
     tf.keras.layers.Dense(2)
])

# %% [markdown]
# ###Compile the model
# As usual, we will use the `adam` optimizer. Since we output a softmax categorization, we'll use we `sparse_categorical_crossentropy` as the loss function. We would also like to look at training and validation accuracy on each epoch as we train our network, so we are passing in matrix argument.

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy']
)

# %% [markdown]
# ##Model Summary
# Let's look at all the layers of our network using summary method.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 17, 17, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 15, 15, 128)       147584
#
#  max_pooling2d_3 (MaxPooling  (None, 7, 7, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dense (Dense)               (None, 512)               3211776
#
#  dense_1 (Dense)             (None, 2)                 1026
#
# =================================================================
# Total params: 3,453,634
# Trainable params: 3,453,634
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #Train the model
# It's time we train our network.
# Since our batches are coming from a generator(`ImageDataGenerator`), we'll use `fit_generator` instead of `fit`

# %%
EPOCHS=100
history = model.fit_generator(
    train_data_gen,
    steps_per_epoch=int(np.ceil(total_train/ float(BATCH_SIZE))),
    epochs=EPOCHS,
    validation_data = val_data_gen,
    validation_steps = int(np.ceil(total_val/float(BATCH_SIZE)))
)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   import sys
# 200/200 [==============================] - 22s 48ms/step - loss: 0.6998 - accuracy: 0.4880 - val_loss: 0.6928 - val_accuracy: 0.5000
# Epoch 2/100
# 200/200 [==============================] - 10s 49ms/step - loss: 0.6956 - accuracy: 0.4935 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 3/100
# 200/200 [==============================] - 10s 49ms/step - loss: 0.6935 - accuracy: 0.4965 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 4/100
# 200/200 [==============================] - 10s 48ms/step - loss: 0.6938 - accuracy: 0.4925 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 5/100
# 200/200 [==============================] - 10s 48ms/step - loss: 0.7011 - accuracy: 0.5100 - val_loss: 0.6930 - val_accuracy: 0.5000
# Epoch 6/100
# 200/200 [==============================] - 10s 48ms/step - loss: 0.6939 - accuracy: 0.5005 - val_loss: 0.6936 - val_accuracy: 0.5000
# Epoch 7/100
# 200/200 [==============================] - 10s 48ms/step - loss: 0.6930 - accuracy: 0.5055 - val_loss: 0.6910 - val_accuracy: 0.5310
# Epoch 8/100
# 200/200 [==============================] - 10s 48ms/step - loss: 0.6895 - accuracy: 0.5350 - val_loss: 0.6901 - val_accuracy: 0.5370
# Epoch 9/100
# 200/200 [==============================] - 10s 48ms/step - loss: 0.6881 - accuracy: 0.5400 - val_loss: 0.6873 - val_accuracy: 0.5570
# Epoch 10/100
# 200/200 [==============================] - 10s 48ms/step - loss: 0.6828 - accuracy: 0.5455 - val_loss: 0.6879 - val_accuracy: 0.5380
# Epoch 11/100
# 200/200 [==============================] - 10s 48ms/step - loss: 0.6773 - accuracy: 0.5630 - val_loss: 0.6948 - val_accuracy: 0.5300
# Epoch 12/100
# 200/200 [==============================] - 10s 48ms/step - loss: 0.6729 - accuracy: 0.5860 - val_loss: 0.6890 - val_accuracy: 0.5660
# Epoch 13/100
# 200/200 [==============================] - 10s 48ms/step - loss: 0.6463 - accuracy: 0.6215 - val_loss: 0.6665 - val_accuracy: 0.5910
# Epoch 14/100
# 200/200 [==============================] - 9s 47ms/step - loss: 0.6132 - accuracy: 0.6615 - val_loss: 0.6720 - val_accuracy: 0.5990
# Epoch 15/100
# 200/200 [==============================] - 10s 48ms/step - loss: 0.5395 - accuracy: 0.7160 - val_loss: 0.6709 - val_accuracy: 0.6440
# Epoch 16/100
# 200/200 [==============================] - 10s 49ms/step - loss: 0.4676 - accuracy: 0.7705 - val_loss: 0.6777 - val_accuracy: 0.6770
# Epoch 17/100
# 200/200 [==============================] - 10s 48ms/step - loss: 0.3428 - accuracy: 0.8400 - val_loss: 0.7525 - val_accuracy: 0.6690
# Epoch 18/100
# 200/200 [==============================] - 10s 48ms/step - loss: 0.2271 - accuracy: 0.9070 - val_loss: 0.9366 - val_accuracy: 0.6580
# Epoch 19/100
# 200/200 [==============================] - 10s 48ms/step - loss: 0.1325 - accuracy: 0.9495 - val_loss: 1.3655 - val_accuracy: 0.6650
# Epoch 20/100
# 200/200 [==============================] - 9s 47ms/step - loss: 0.0602 - accuracy: 0.9785 - val_loss: 1.7544 - val_accuracy: 0.6520
# Epoch 21/100
# 200/200 [==============================] - 10s 48ms/step - loss: 0.0544 - accuracy: 0.9825 - val_loss: 1.7685 - val_accuracy: 0.6550
# Epoch 22/100
# 200/200 [==============================] - 10s 48ms/step - loss: 0.0200 - accuracy: 0.9960 - val_loss: 2.1254 - val_accuracy: 0.6580
# Epoch 23/100
# 200/200 [==============================] - 10s 48ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 2.2933 - val_accuracy: 0.6590
# Epoch 24/100
# 200/200 [==============================] - 10s 47ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 2.5338 - val_accuracy: 0.6610
# Epoch 25/100
# 200/200 [==============================] - 11s 53ms/step - loss: 0.0338 - accuracy: 0.9875 - val_loss: 1.8927 - val_accuracy: 0.6420
# Epoch 26/100
# 200/200 [==============================] - 10s 48ms/step - loss: 0.0514 - accuracy: 0.9855 - val_loss: 1.9164 - val_accuracy: 0.6450
# Epoch 27/100
# 200/200 [==============================] - 10s 48ms/step - loss: 0.0406 - accuracy: 0.9865 - val_loss: 2.1350 - val_accuracy: 0.6450
# Epoch 28/100
# 200/200 [==============================] - 10s 48ms/step - loss: 0.0113 - accuracy: 0.9985 - val_loss: 2.4545 - val_accuracy: 0.6500
# Epoch 29/100
# 200/200 [==============================] - 9s 47ms/step - loss: 0.0084 - accuracy: 0.9985 - val_loss: 2.6132 - val_accuracy: 0.6330
# Epoch 30/100
# 200/200 [==============================] - 9s 47ms/step - loss: 6.9156e-04 - accuracy: 1.0000 - val_loss: 2.6748 - val_accuracy: 0.6470
# Epoch 31/100
# 200/200 [==============================] - 10s 48ms/step - loss: 3.6933e-04 - accuracy: 1.0000 - val_loss: 2.7405 - val_accuracy: 0.6420
# Epoch 32/100
# 200/200 [==============================] - 12s 60ms/step - loss: 1.5149e-04 - accuracy: 1.0000 - val_loss: 2.7864 - val_accuracy: 0.6370
# Epoch 33/100
# 200/200 [==============================] - 9s 47ms/step - loss: 1.0634e-04 - accuracy: 1.0000 - val_loss: 2.8265 - val_accuracy: 0.6390
# Epoch 34/100
# 200/200 [==============================] - 10s 48ms/step - loss: 7.7816e-05 - accuracy: 1.0000 - val_loss: 2.9206 - val_accuracy: 0.6400
# Epoch 35/100
# 200/200 [==============================] - 10s 48ms/step - loss: 4.6106e-05 - accuracy: 1.0000 - val_loss: 3.0968 - val_accuracy: 0.6450
# Epoch 36/100
# 200/200 [==============================] - 10s 48ms/step - loss: 2.3920e-05 - accuracy: 1.0000 - val_loss: 3.3075 - val_accuracy: 0.6490
# Epoch 37/100
# 200/200 [==============================] - 10s 48ms/step - loss: 1.6727e-05 - accuracy: 1.0000 - val_loss: 3.3586 - val_accuracy: 0.6530
# Epoch 38/100
# 200/200 [==============================] - 9s 47ms/step - loss: 1.1537e-05 - accuracy: 1.0000 - val_loss: 3.4293 - val_accuracy: 0.6420
# Epoch 39/100
# 200/200 [==============================] - 9s 47ms/step - loss: 1.0104e-05 - accuracy: 1.0000 - val_loss: 3.4532 - val_accuracy: 0.6530
# Epoch 40/100
# 200/200 [==============================] - 10s 48ms/step - loss: 7.7836e-06 - accuracy: 1.0000 - val_loss: 3.5077 - val_accuracy: 0.6540
# Epoch 41/100
# 200/200 [==============================] - 10s 49ms/step - loss: 6.2965e-06 - accuracy: 1.0000 - val_loss: 3.5740 - val_accuracy: 0.6490
# Epoch 42/100
# 200/200 [==============================] - 13s 67ms/step - loss: 4.1109e-07 - accuracy: 1.0000 - val_loss: 4.0589 - val_accuracy: 0.6510
# Epoch 63/100
# 200/200 [==============================] - 13s 67ms/step - loss: 3.7372e-07 - accuracy: 1.0000 - val_loss: 4.0667 - val_accuracy: 0.6530
# Epoch 64/100
# 200/200 [==============================] - 13s 67ms/step - loss: 3.3283e-07 - accuracy: 1.0000 - val_loss: 4.0982 - val_accuracy: 0.6530
# Epoch 65/100
# 200/200 [==============================] - 11s 56ms/step - loss: 2.9933e-07 - accuracy: 1.0000 - val_loss: 4.1177 - val_accuracy: 0.6530
# Epoch 66/100
# 200/200 [==============================] - 10s 48ms/step - loss: 2.7394e-07 - accuracy: 1.0000 - val_loss: 4.1320 - val_accuracy: 0.6540
# Epoch 67/100
# 200/200 [==============================] - 13s 65ms/step - loss: 2.4492e-07 - accuracy: 1.0000 - val_loss: 4.1555 - val_accuracy: 0.6530
# Epoch 68/100
# 200/200 [==============================] - 13s 63ms/step - loss: 2.2113e-07 - accuracy: 1.0000 - val_loss: 4.1741 - val_accuracy: 0.6520
# Epoch 69/100
# 200/200 [==============================] - 9s 47ms/step - loss: 2.0200e-07 - accuracy: 1.0000 - val_loss: 4.1907 - val_accuracy: 0.6510
# Epoch 70/100
# 200/200 [==============================] - 10s 52ms/step - loss: 1.8305e-07 - accuracy: 1.0000 - val_loss: 4.2168 - val_accuracy: 0.6520
# Epoch 71/100
# 200/200 [==============================] - 10s 49ms/step - loss: 1.6624e-07 - accuracy: 1.0000 - val_loss: 4.2262 - val_accuracy: 0.6520
# Epoch 72/100
# 200/200 [==============================] - 10s 48ms/step - loss: 1.5342e-07 - accuracy: 1.0000 - val_loss: 4.2345 - val_accuracy: 0.6510
# Epoch 73/100
# 200/200 [==============================] - 10s 52ms/step - loss: 1.3846e-07 - accuracy: 1.0000 - val_loss: 4.2632 - val_accuracy: 0.6520
# Epoch 74/100
# 200/200 [==============================] - 10s 51ms/step - loss: 1.2583e-07 - accuracy: 1.0000 - val_loss: 4.2773 - val_accuracy: 0.6510
# Epoch 75/100
# 200/200 [==============================] - 15s 74ms/step - loss: 1.1379e-07 - accuracy: 1.0000 - val_loss: 4.2949 - val_accuracy: 0.6500
# Epoch 76/100
# 200/200 [==============================] - 11s 54ms/step - loss: 1.0449e-07 - accuracy: 1.0000 - val_loss: 4.3197 - val_accuracy: 0.6500
# Epoch 77/100
# 200/200 [==============================] - 10s 48ms/step - loss: 9.5963e-08 - accuracy: 1.0000 - val_loss: 4.3360 - val_accuracy: 0.6500
# Epoch 78/100
# 200/200 [==============================] - 10s 48ms/step - loss: 8.5831e-08 - accuracy: 1.0000 - val_loss: 4.3558 - val_accuracy: 0.6470
# Epoch 79/100
# 200/200 [==============================] - 11s 57ms/step - loss: 7.8678e-08 - accuracy: 1.0000 - val_loss: 4.3700 - val_accuracy: 0.6490
# Epoch 80/100
# 200/200 [==============================] - 16s 79ms/step - loss: 7.0214e-08 - accuracy: 1.0000 - val_loss: 4.3924 - val_accuracy: 0.6490
# Epoch 81/100
# 200/200 [==============================] - 12s 62ms/step - loss: 6.5684e-08 - accuracy: 1.0000 - val_loss: 4.4111 - val_accuracy: 0.6480
# Epoch 82/100
# 200/200 [==============================] - 13s 63ms/step - loss: 6.0320e-08 - accuracy: 1.0000 - val_loss: 4.4200 - val_accuracy: 0.6480
# Epoch 83/100
# 200/200 [==============================] - 10s 48ms/step - loss: 5.5015e-08 - accuracy: 1.0000 - val_loss: 4.4344 - val_accuracy: 0.6460
# Epoch 84/100
# 200/200 [==============================] - 10s 48ms/step - loss: 5.0306e-08 - accuracy: 1.0000 - val_loss: 4.4585 - val_accuracy: 0.6460
# Epoch 85/100
# 200/200 [==============================] - 10s 48ms/step - loss: 4.6134e-08 - accuracy: 1.0000 - val_loss: 4.4675 - val_accuracy: 0.6470
# Epoch 86/100
# 200/200 [==============================] - 10s 48ms/step - loss: 4.1544e-08 - accuracy: 1.0000 - val_loss: 4.4953 - val_accuracy: 0.6460
# Epoch 87/100
# 200/200 [==============================] - 10s 48ms/step - loss: 3.7313e-08 - accuracy: 1.0000 - val_loss: 4.5100 - val_accuracy: 0.6470
# Epoch 88/100
# 200/200 [==============================] - 10s 48ms/step - loss: 3.4988e-08 - accuracy: 1.0000 - val_loss: 4.5293 - val_accuracy: 0.6490
# Epoch 89/100
# 200/200 [==============================] - 10s 51ms/step - loss: 3.1948e-08 - accuracy: 1.0000 - val_loss: 4.5454 - val_accuracy: 0.6450
# Epoch 90/100
# 200/200 [==============================] - 11s 56ms/step - loss: 2.9445e-08 - accuracy: 1.0000 - val_loss: 4.5669 - val_accuracy: 0.6500
# Epoch 91/100
# 200/200 [==============================] - 10s 49ms/step - loss: 2.6107e-08 - accuracy: 1.0000 - val_loss: 4.5893 - val_accuracy: 0.6480
# Epoch 92/100
# 200/200 [==============================] - 10s 48ms/step - loss: 2.3842e-08 - accuracy: 1.0000 - val_loss: 4.6096 - val_accuracy: 0.6480
# Epoch 93/100
# 200/200 [==============================] - 10s 48ms/step - loss: 2.1935e-08 - accuracy: 1.0000 - val_loss: 4.6332 - val_accuracy: 0.6500
# Epoch 94/100
# 200/200 [==============================] - 10s 48ms/step - loss: 1.9789e-08 - accuracy: 1.0000 - val_loss: 4.6431 - val_accuracy: 0.6500
# Epoch 95/100
# 200/200 [==============================] - 10s 48ms/step - loss: 1.8060e-08 - accuracy: 1.0000 - val_loss: 4.6636 - val_accuracy: 0.6490
# Epoch 96/100
# 200/200 [==============================] - 11s 53ms/step - loss: 1.6093e-08 - accuracy: 1.0000 - val_loss: 4.6862 - val_accuracy: 0.6520
# Epoch 97/100
# 200/200 [==============================] - 10s 48ms/step - loss: 1.4842e-08 - accuracy: 1.0000 - val_loss: 4.7120 - val_accuracy: 0.6500
# Epoch 98/100
# 200/200 [==============================] - 10s 48ms/step - loss: 1.3411e-08 - accuracy: 1.0000 - val_loss: 4.7264 - val_accuracy: 0.6500
# Epoch 99/100
# 200/200 [==============================] - 10s 48ms/step - loss: 1.1921e-08 - accuracy: 1.0000 - val_loss: 4.7486 - val_accuracy: 0.6500
# Epoch 100/100
# 200/200 [==============================] - 10s 48ms/step - loss: 1.0788e-08 - accuracy: 1.0000 - val_loss: 4.7740 - val_accuracy: 0.6490

# %% [markdown]
# #Visualizing results of the training
# We'll now visualize the results we get after training our network.

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.savefig('./foo.png')
plt.show()

# %% [markdown]
# As we can see from the plots, training accuracy and validation accuracy are off by large margin and our model has achieved only around **70%** accuracy on the validation set (depending on the number of epochs you trained for).
#
# This is a clear indication of overfitting. Once the training and validation curves start to diverge, our model has started to memorize the training data and is unable to perform well on alidation data.
